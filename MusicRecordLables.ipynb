# %%
import pandas as pd
import requests
import time
from sqlalchemy import create_engine

# %%
print('Begin reading new label releases from discogs.com')
discogs_df = pd.read_xml('https://discogs-data-dumps.s3-us-west-2.amazonaws.com/data/2023/discogs_20230101_labels.xml.gz')
print(f'Successfully loaded {discogs_df.shape[0]} labels into DataFrame')
# Out:
# Begin reading new label releases from discogs.com
# Successfully loaded 1946246 labels into DataFrame

# %%
print('Begin cleaning columns')
# Out:
# Begin cleaning columns

# %%
discogs_df.head()
# Out:
#    images  id                   name  \
# 0     NaN   1               Planet E
# 1     NaN   2  Earthtones Recordings
# 2     NaN   3     Seasons Recordings
# 3     NaN   4           Siesta Music
# 4     NaN   5                   Svek
#
#                                          contactinfo  \
# 0  Planet E Communications\r\nP.O. Box 27218\r\nD...
# 1  Seasons Recordings\r\n2236 Pacific Avenue\r\nS...
# 2  Seasons Recordings\r\nCosta Mesa, CA 92627\r\n...
# 3  Siesta Records\r\n1913 Via Encantadoras\r\nSan...
# 4  Svek office \r\nStephan Grieder \r\nFax: +46 (...
#
#                                              profile data_quality  urls  \
# 0  [a=Carl Craig]'s classic techno label founded ...   Needs Vote   NaN
# 1  California deep house label founded by [a=Jami...      Correct   NaN
# 2  California deep-house label founded by [a=Jami...   Needs Vote   NaN
# 3                                               None   Needs Vote   NaN
# 4                                               None      Correct   NaN
#
#    sublabels     parentLabel
# 0        NaN            None
# 1        NaN            None
# 2        NaN            None
# 3        NaN            None
# 4        NaN  Goldhead Music

# %%
discogs_df = discogs_df[discogs_df.data_quality == 'Complete and Correct']

# %%
discogs_df = discogs_df.dropna(subset='contactinfo')

# %%
discogs_df = discogs_df.drop(['images', 'data_quality', 'urls', 'sublabels'], axis=1)

# %%
print(f'Completed cleaning columns {discogs_df.shape[0]} labels')
print(f'Begin API calls for additional label info ({discogs_df.shape[0]} labels)')
# Out:
# Completed cleaning columns 430 labels
# Begin API calls for additional label info (430 labels)

# %%
token = 'eGPWhsVlMrbyFElTkhujTZgtitsyOkVDxZDNRDPy'
base_url = 'https://api.discogs.com/'

def api_data(x:int):
  try:
    response = requests.get(f'{base_url}labels/{x}/releases',
                            params={'oauth_token': token})
    time.sleep(2)
    return response.json()
  except Exception:
    print(f'Failed API call for label {x}')
    time.sleep(60)

# %%
discogs_df['json'] = discogs_df.id.apply(api_data)

# %%
def get_count(x) -> int:
  count = int(x['pagination']['items'])
  return count

def get_min(x):
  year_list = list()
  for i in x['releases']:
    year_list.append(i['year'])
  year_list_cleaned = [n for n in year_list if n > 1800]
  year_list_cleaned.sort()
  if len(year_list_cleaned) > 0:
    min = int(year_list_cleaned[0])
    return min
  else:
    return None

def get_max(x):
  year_list = list()
  for i in x['releases']:
    year_list.append(i['year'])
  year_list_cleaned = [n for n in year_list if n > 1800]
  year_list_cleaned.sort()
  if len(year_list_cleaned) > 0:
    max = int(year_list_cleaned[-1])
    return max
  else:
    return None

# %%
discogs_df['max_release_year'] = discogs_df.json.apply(get_max)
discogs_df['min_release_year'] = discogs_df.json.apply(get_min)
discogs_df['num_of_releases'] = discogs_df.json.apply(get_count)

# %%
discogs_df
# Out:
#               id                                name  \
# 725          774                   Hed Kandi Records
# 2878        3141                             Concept
# 2935        3203                  Tinnitus Tonträger
# 3020        3295                  Taaach! Recordings
# 3505        3824                                Fuse
# ...          ...                                 ...
# 1837333  2731304                ELUSIVE INTELLIGENCE
# 1838109  2733764                  Axe & Trap Studios
# 1854531  2786228                              Εν Πλω
# 1882605  2875724  Doppelkirche Bonn-Schwarzrheindorf
# 1918553  2990383                          Imp. Nasra
#
#                                                contactinfo  \
# 725      MSHK Limited\r\n103 Gaunt Street\r\nLondon, SE...
# 2878     Concept Records\r\n24A Barry Street\r\nBradfor...
# 2935     Tinnitus Tonträger\r\nMarc Göttling\r\nWiesent...
# 3020     Taaach!\r\nEdition Chrome\r\nPostfach 10 50 54...
# 3505     Fuse\r\nbkb Dance Department gmbh\r\nAuhofstra...
# ...                                                    ...
# 1837333           childhoodintelligenceworldwide@gmail.com
# 1838109  Underwood Business Park\r\nWookey Hole Road\r\...
# 1854531  Κολοκοτρώνη 49, 105 60 Αθήνα\r\n+302103226343 ...
# 1882605  Doppelkirche St. Maria und St. Clemens\r\nDixs...
# 1918553               Imp. Nasra\r\n3, Rue Vesoul\r\nTunis
#
#                                                    profile  \
# 725      Record company of the UK-based house label [l6...
# 2878     Trance label from the UK. The label becomes [l...
# 2935             Style: hard kicking minimal techno traxx.
# 3020     German Trance Label\r\nDistributed by InterGro...
# 3505     German Trance label\r\nDistributed by Music Ma...
# ...                                                    ...
# 1837333                                               None
# 1838109  Recording studio located in the city of Wells,...
# 1854531          Publishing company for books, music etc..
# 1882605  Catholic parish church in Romanesque style fro...
# 1918553                Printing company located in Tunisia
#
#                     parentLabel  \
# 725           Ministry Of Sound
# 2878        Global Beat Records
# 2935                       None
# 3020                       None
# 3505            Massive Records
# ...                         ...
# 1837333  Childhood Intelligence
# 1838109                    None
# 1854531                    None
# 1882605                    None
# 1918553                    None
#
#                                                       json  max_release_year  \
# 725      {'pagination': {'page': 1, 'pages': 14, 'per_p...            2002.0
# 2878     {'pagination': {'page': 1, 'pages': 1, 'per_pa...            1996.0
# 2935     {'pagination': {'page': 1, 'pages': 1, 'per_pa...            2002.0
# 3020     {'pagination': {'page': 1, 'pages': 1, 'per_pa...            2001.0
# 3505     {'pagination': {'page': 1, 'pages': 1, 'per_pa...            2001.0
# ...                                                    ...               ...
# 1837333  {'pagination': {'page': 1, 'pages': 1, 'per_pa...            2022.0
# 1838109  {'pagination': {'page': 1, 'pages': 1, 'per_pa...            2024.0
# 1854531  {'pagination': {'page': 1, 'pages': 1, 'per_pa...            2021.0
# 1882605  {'pagination': {'page': 1, 'pages': 1, 'per_pa...               NaN
# 1918553  {'pagination': {'page': 1, 'pages': 1, 'per_pa...            1972.0
#
#          min_release_year  num_of_releases
# 725                1999.0              655
# 2878               1996.0                4
# 2935               1999.0               11
# 3020               1998.0               29
# 3505               1997.0               33
# ...                   ...              ...
# 1837333            2022.0                5
# 1838109            2019.0               29
# 1854531            2021.0                1
# 1882605               NaN                2
# 1918553            1972.0                1
#
# [430 rows x 9 columns]

# %%
labels_df = discogs_df[['id', 'name', 'contactinfo', 'profile', 'parentLabel', 'num_of_releases', 'min_release_year', 'max_release_year']]

# %%
labels_df
# Out:
#               id                                name  \
# 725          774                   Hed Kandi Records
# 2878        3141                             Concept
# 2935        3203                  Tinnitus Tonträger
# 3020        3295                  Taaach! Recordings
# 3505        3824                                Fuse
# ...          ...                                 ...
# 1837333  2731304                ELUSIVE INTELLIGENCE
# 1838109  2733764                  Axe & Trap Studios
# 1854531  2786228                              Εν Πλω
# 1882605  2875724  Doppelkirche Bonn-Schwarzrheindorf
# 1918553  2990383                          Imp. Nasra
#
#                                                contactinfo  \
# 725      MSHK Limited\r\n103 Gaunt Street\r\nLondon, SE...
# 2878     Concept Records\r\n24A Barry Street\r\nBradfor...
# 2935     Tinnitus Tonträger\r\nMarc Göttling\r\nWiesent...
# 3020     Taaach!\r\nEdition Chrome\r\nPostfach 10 50 54...
# 3505     Fuse\r\nbkb Dance Department gmbh\r\nAuhofstra...
# ...                                                    ...
# 1837333           childhoodintelligenceworldwide@gmail.com
# 1838109  Underwood Business Park\r\nWookey Hole Road\r\...
# 1854531  Κολοκοτρώνη 49, 105 60 Αθήνα\r\n+302103226343 ...
# 1882605  Doppelkirche St. Maria und St. Clemens\r\nDixs...
# 1918553               Imp. Nasra\r\n3, Rue Vesoul\r\nTunis
#
#                                                    profile  \
# 725      Record company of the UK-based house label [l6...
# 2878     Trance label from the UK. The label becomes [l...
# 2935             Style: hard kicking minimal techno traxx.
# 3020     German Trance Label\r\nDistributed by InterGro...
# 3505     German Trance label\r\nDistributed by Music Ma...
# ...                                                    ...
# 1837333                                               None
# 1838109  Recording studio located in the city of Wells,...
# 1854531          Publishing company for books, music etc..
# 1882605  Catholic parish church in Romanesque style fro...
# 1918553                Printing company located in Tunisia
#
#                     parentLabel  num_of_releases  min_release_year  \
# 725           Ministry Of Sound              655            1999.0
# 2878        Global Beat Records                4            1996.0
# 2935                       None               11            1999.0
# 3020                       None               29            1998.0
# 3505            Massive Records               33            1997.0
# ...                         ...              ...               ...
# 1837333  Childhood Intelligence                5            2022.0
# 1838109                    None               29            2019.0
# 1854531                    None                1            2021.0
# 1882605                    None                2               NaN
# 1918553                    None                1            1972.0
#
#          max_release_year
# 725                2002.0
# 2878               1996.0
# 2935               2002.0
# 3020               2001.0
# 3505               2001.0
# ...                   ...
# 1837333            2022.0
# 1838109            2024.0
# 1854531            2021.0
# 1882605               NaN
# 1918553            1972.0
#
# [430 rows x 8 columns]

# %%
database_url = 'postgresql://postgres.mecvsqfdytymqtblrlgo:TWZ7i7KeGaFF@aws-0-us-west-1.pooler.supabase.com:6543/postgres'
engine = create_engine(database_url)

# %%
with engine.connect() as con:
    labels_df.to_sql("labels", con, index=False)

# %%
with engine.connect() as con:
    display(pd.read_sql('SELECT * FROM labels', con))
# Out:
#           id                                name  \
# 0        774                   Hed Kandi Records
# 1       3141                             Concept
# 2       3203                  Tinnitus Tonträger
# 3       3295                  Taaach! Recordings
# 4       3824                                Fuse
# ..       ...                                 ...
# 425  2731304                ELUSIVE INTELLIGENCE
# 426  2733764                  Axe & Trap Studios
# 427  2786228                              Εν Πλω
# 428  2875724  Doppelkirche Bonn-Schwarzrheindorf
# 429  2990383                          Imp. Nasra
#
#                                            contactinfo  \
# 0    MSHK Limited\r\n103 Gaunt Street\r\nLondon, SE...
# 1    Concept Records\r\n24A Barry Street\r\nBradfor...
# 2    Tinnitus Tonträger\r\nMarc Göttling\r\nWiesent...
# 3    Taaach!\r\nEdition Chrome\r\nPostfach 10 50 54...
# 4    Fuse\r\nbkb Dance Department gmbh\r\nAuhofstra...
# ..                                                 ...
# 425           childhoodintelligenceworldwide@gmail.com
# 426  Underwood Business Park\r\nWookey Hole Road\r\...
# 427  Κολοκοτρώνη 49, 105 60 Αθήνα\r\n+302103226343 ...
# 428  Doppelkirche St. Maria und St. Clemens\r\nDixs...
# 429               Imp. Nasra\r\n3, Rue Vesoul\r\nTunis
#
#                                                profile  \
# 0    Record company of the UK-based house label [l6...
# 1    Trance label from the UK. The label becomes [l...
# 2            Style: hard kicking minimal techno traxx.
# 3    German Trance Label\r\nDistributed by InterGro...
# 4    German Trance label\r\nDistributed by Music Ma...
# ..                                                 ...
# 425                                               None
# 426  Recording studio located in the city of Wells,...
# 427          Publishing company for books, music etc..
# 428  Catholic parish church in Romanesque style fro...
# 429                Printing company located in Tunisia
#
#                 parentLabel  num_of_releases  min_release_year  \
# 0         Ministry Of Sound              655            1999.0
# 1       Global Beat Records                4            1996.0
# 2                      None               11            1999.0
# 3                      None               29            1998.0
# 4           Massive Records               33            1997.0
# ..                      ...              ...               ...
# 425  Childhood Intelligence                5            2022.0
# 426                    None               29            2019.0
# 427                    None                1            2021.0
# 428                    None                2               NaN
# 429                    None                1            1972.0
#
#      max_release_year
# 0              2002.0
# 1              1996.0
# 2              2002.0
# 3              2001.0
# 4              2001.0
# ..                ...
# 425            2022.0
# 426            2024.0
# 427            2021.0
# 428               NaN
# 429            1972.0
#
# [430 rows x 8 columns]
